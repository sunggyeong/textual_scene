# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
ZIP_PATH = "/content/drive/MyDrive/SNU_AI_Challenge/snuaichallenge.zip"

# !unzip -l "$ZIP_PATH" | head -30

# %%
# !unzip -q "$ZIP_PATH" -d "/content/"

# %%
# !ls -al "/content/snuaichallenge_data"
# !ls "/content/snuaichallenge_data/test" | head

# %%
### os ??? ? ??? ?? ??
# ? ? True? ????

# %%
import os

print(os.path.exists("/content/snuaichallenge_data/test.csv"))
print(os.path.isdir("/content/snuaichallenge_data/test"))

# %%
# %pip install -q torch torchvision transformers pandas pillow tqdm accelerate qwen-vl-utils

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
MODEL_NAME = "Qwen/Qwen2-VL-2B-Instruct"

OUTPUT_DIR = "/content/outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

DATA_DIR = "/content/snuaichallenge_data"
TEST_CSV = os.path.join(DATA_DIR, "test.csv")
TEST_IMAGE_DIR = os.path.join(DATA_DIR, "test")

print("device:", device)
print("test.csv:", TEST_CSV)
print("test images:", TEST_IMAGE_DIR)

# %% [markdown]
# device: cuda
# test.csv: /content/snuaichallenge_data/test.csv
# test images: /content/snuaichallenge_data/test

# %%
assert os.path.exists(TEST_CSV), f"test.csv가 없습니다: {TEST_CSV}"
assert os.path.isdir(TEST_IMAGE_DIR), f"test 폴더가 없습니다: {TEST_IMAGE_DIR}"

print("데이터 경로 확인 완료")
